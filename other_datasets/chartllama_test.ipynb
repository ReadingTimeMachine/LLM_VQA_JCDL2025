# %%
data_dir = '~/Downloads/tmp/JCDL2025/other_datasets/ChartLlama/'

# %%
import json

# %%
with open(data_dir + 'heatmap_chart_100examples_simplified_qa.json','r') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'id': 'ours_simplified_qa_38_2',
#   'image': 'ours/heatmap_chart/png/heatmap_chart_100examples_38.png',
#   'model': '',
#   'conversations': [{'from': 'human',
#     'value': '\nWhat was the number of road safety incidents in South America in 2018?'},
#    {'from': 'gpt', 'value': '7000'}]},
#  {'id': 'ours_simplified_qa_27_4',
#   'image': 'ours/heatmap_chart/png/heatmap_chart_100examples_27.png',
#   'model': '',
#   'conversations': [{'from': 'human',
#     'value': 'Does the heatmap indicate a decline in recycling habits for Middle Aged individuals?\n'},
#    {'from': 'gpt', 'value': 'Yes'}]},
#  {'id': 'ours_simplified_qa_71_0',
#   'image': 'ours/heatmap_chart/png/heatmap_chart_100examples_71.png',
#   'model': '',
#   'conversations': [{'from': 'human',
#     'value': 'What is the impact on bear population due to urbanization in 1970?\n'},
#    {'from': 'gpt', 'value': '50'}]},
#  {'id': 'ours_simplified_qa_35_8',
# ...
