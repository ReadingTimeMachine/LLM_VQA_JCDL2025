# %%
data_dir = '/Users/jnaiman/Downloads/tmp/JCDL2025/other_datasets/AutoChart/autochart-master/Chart Information/'

# %%
import json

# %%
with open(data_dir +'all_Bar.json','r') as f:
    data1 = json.load(f)

# %%
data1[0]
# Out:
# {'image_index': 0,
#  'type': 'bar_chart',
#  'image_axes_bbox': {'y': 30.000000000000043,
#   'w': 3140.0,
#   'h': 1539.9999999999995,
#   'x': 29.99999999999997},
#  'color': 'blue',
#  'title': {'text': 'Percentage of part-time workers in Luxembourg',
#   'bbox': {'y': 1517.9999999999995,
#    'w': 995.75,
#    'h': 42.0,
#    'x': 1154.9027777777778}},
#  'x_axis': {'tick_labels': {'value': ['1991', '1992', '1993', '1994', '1995'],
#    'bboxes': [{'y': 73.11111111111116,
#      'w': 105.75,
#      'h': 42.0,
#      'x': 339.94689713224193},
#     {'y': 73.11111111111116, 'w': 105.625, 'h': 42.0, 'x': 969.9873374550098},
#     {'y': 73.11111111111116, 'w': 105.875, 'h': 42.0, 'x': 1599.8402777777776},
#     {'y': 73.11111111111116, 'w': 105.75, 'h': 42.0, 'x': 2229.8807181005454},
#     {'y': 73.11111111111116,
#      'w': 105.75,
#      'h': 42.0,
#      'x': 2859.8586584233135}]},
#   'label': {'text': 'Year',
#    'bbox': {'y': 20.000000000000043,
#     'w': 88.125,
# ...
