# %%
from datasets import load_dataset

#ds = load_dataset("alexshengzhili/SciGraphQA-295K-train") # get HTTP requests error
ds = load_dataset("alexshengzhili/SciCapInstructed-graph-only-qa")
# Out:
# README.md:   0%|          | 0.00/630 [00:00<?, ?B/s]
# data/1_percent_as_validation-00000-of-00(…):   0%|          | 0.00/7.89M [00:00<?, ?B/s]
# Generating 1_percent_as_validation split:   0%|          | 0/3002 [00:00<?, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     1_percent_as_validation: Dataset({
#         features: ['image_file', 'id', 'caption', 'conversations', 'first_mention', 'response', 'title', 'abstract', 'q_a_pairs'],
#         num_rows: 3002
#     })
# })

# %%
ds['1_percent_as_validation'].to_pandas()
# Out:
#                        image_file                       id  \
# 0     1801.01974v2-Figure10-1.png  1801.01974v2-Figure10-1
# 1      1801.05671v1-Figure9-1.png   1801.05671v1-Figure9-1
# 2      2004.06653v1-Figure9-1.png   2004.06653v1-Figure9-1
# 3      1803.06598v1-Figure8-1.png   1803.06598v1-Figure8-1
# 4      2004.04071v2-Figure7-1.png   2004.04071v2-Figure7-1
# ...                           ...                      ...
# 2997   1906.03310v2-Figure3-1.png   1906.03310v2-Figure3-1
# 2998   1505.00130v2-Figure7-1.png   1505.00130v2-Figure7-1
# 2999   2006.02286v3-Figure9-1.png   2006.02286v3-Figure9-1
# 3000   1806.02887v1-Figure2-1.png   1806.02887v1-Figure2-1
# 3001   2004.06366v1-Figure5-1.png   2004.06366v1-Figure5-1
#
#                                                 caption  \
# 0     Fig. 10. Average AUC and AUPR versus the numbe...
# 1     Figure 9: Static target and PPS modulation: hu...
# 2                            Figure 9: The effect of θ.
# ...
