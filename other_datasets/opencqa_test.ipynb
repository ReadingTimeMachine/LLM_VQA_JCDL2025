# %%
dir_data = '/Users/jnaiman/Downloads/tmp/JCDL2025/other_datasets/OpenCQA/'

# %%
import pandas as pd

# %%
#df_full = pd.read_json(dir_data + 'etc/data(full_summary_article)/full_dataset_extended.json')
df_full = pd.read_csv(dir_data + 'etc/data(full_summary_article)/all_annotations_extended.csv')

# %%
df_full.head()
# Out:
#    Unnamed: 0                                img_path  \
# 0           0  mturk_charts/no_data/two_col/24293.png
# 1           1  mturk_charts/no_data/two_col/22662.png
# 2           2  mturk_charts/no_data/two_col/22605.png
# 3           3  mturk_charts/no_data/two_col/22594.png
# 4           4  mturk_charts/no_data/two_col/22441.png
#
#                                              summary question_resolution  \
# 0  As the following charts show , the differences...                same
# 1  By and large , European Muslims – irrespective...                same
# 2  Despite their relatively secular worldview , L...                same
# 3  Despite their relatively secular worldview , L...                same
# 4  On a typical day in August , 26 million Americ...                same
#
#                                             question answer_resolution  \
# 0  Compare the proportion of dial-up users and br...           answer1
# ...
