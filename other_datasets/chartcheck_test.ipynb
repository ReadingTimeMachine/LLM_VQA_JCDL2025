# %%
dir_dat = '/Users/jnaiman/Downloads/tmp/JCDL2025/other_datasets/chartfc_dataset_wikicommons/data/dataset/'

# %%
import pandas as pd

# %%
df_barv = pd.read_json(dir_dat + 'barchart_vertical.json')

# %%
df_barv.head()
# Out:
#                                                  0    \
# 0  {'file_name': '160516_Figure2.png', 'type': 'b...
#
#                                                  1    \
# 0  {'file_name': '1831_Occupational_Graph.jpg', '...
#
#                                                  2    \
# 0  {'file_name': '1881_Ashleyhay_Occupation_Chart...
#
#                                                  3    \
# 0  {'file_name': '1881_Occupation_Structure_chart...
#
#                                                  4    \
# 0  {'file_name': '1881_Occupational_orders.png', ...
#
#                                                  5    \
# 0  {'file_name': '1881_Occupational_Structure_of_...
#
#                                                  6    \
# 0  {'file_name': '1881_Occupational_Structure_of_...
#
#                                                  7    \
# 0  {'file_name': '1881_Occupational_Structure_of_...
#
#                                                  8    \
# ...
