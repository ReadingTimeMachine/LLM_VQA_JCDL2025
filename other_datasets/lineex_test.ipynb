# %%
data_dir = '/Users/jnaiman/Downloads/tmp/JCDL2025/other_datasets/LineEX/test/anno/'

# %%
import json

# %%
with open(data_dir + 'line_anno.json','r') as f:
    data_l = json.load(f)

# %%
data_l.keys()
# Out:
# dict_keys(['licenses', 'images', 'annotations', 'categories'])

# %%
data_l['categories']
# Out:
# [{'supercategory': 'Series', 'id': 0, 'name': 'Series'}]

# %%
for d in data_l['annotations']:
    if d['image_id'] == 0:
        print(d)
# Out:
# {'image_id': 0, 'category_id': 0, 'area': 0, 'id': 0, 'bbox': [100.73232323232324, 302.39059217096474, 130.9111952861953, 286.3388404216148, 161.09006734006735, 267.3934558011424, 191.26893939393938, 278.85644778228925, 221.44781144781143, 248.7124662695769, 251.6266835016835, 253.33674207437434, 281.8055555555555, 229.58425891287334, 311.98442760942754, 239.2653272546995, 342.1632996632996, 228.51037675417865, 372.3421717171716, 205.7225133701868, 402.5210437710437, 208.65990356755356, 432.6999158249157, 175.4577158974389, 462.87878787878776, 179.26575315198897], 'raw': [20.0, 83.16392204256664, 28.333333333333336, 83.28206150344839, 36.66666666666667, 83.4214978441176, 45.0, 83.3371312457618, 53.333333333333336, 83.55898826051941, 61.66666666666667, 83.52495400313256, 70.0, 83.69977016021748, 78.33333333333334, 83.62851836087982, 86.66666666666667, 83.70767383710334, 95.0, 83.87539047868053, 103.33333333333334, 83.85377154887554, 111.66666666666667, 84.09813668812589, 120.0, 84.070
# ...

# %%
with open(data_dir + 'cls_anno.json','r') as f:
    data_c = json.load(f)

# %%
data_c.keys()
# Out:
# dict_keys(['licenses', 'images', 'annotations', 'categories'])

# %%
data_c['categories']
# Out:
# [{'supercategory': 'ValueAxisTitle', 'id': 0, 'name': 'ValueAxisTitle'},
#  {'supercategory': 'ChartTitle', 'id': 1, 'name': 'ChartTitle'},
#  {'supercategory': 'CategoryAxisTitle', 'id': 2, 'name': 'CategoryAxisTitle'},
#  {'supercategory': 'InnerPlotArea', 'id': 3, 'name': 'InnerPlotArea'},
#  {'supercategory': 'XTick', 'id': 4, 'name': 'XTick'},
#  {'supercategory': 'YTick', 'id': 5, 'name': 'YTick'},
#  {'supercategory': 'LegendMarker', 'id': 6, 'name': 'LegendMarker'},
#  {'supercategory': 'LegendText', 'id': 7, 'name': 'LegendText'}]

# %%
for dc in data_c['annotations']:
    if dc['image_id'] == 0:
        print(dc)
# Out:
# {'image_id': 0, 'category_id': 0, 'bbox': [488.62499999999994, 196.43055555555551, 196.37500000000006, 117.7777777777778], 'area': 23128.61111111112, 'id': 0}
# {'image_id': 0, 'category_id': 1, 'bbox': [15.000000000000012, 160.41666666666663, 14.000000000000002, 56.75], 'area': 794.5000000000001, 'text': 'sivt 625 ', 'id': 1}
# {'image_id': 0, 'category_id': 2, 'bbox': [253.93055555555554, 15.0, 55.75, 21.0], 'area': 1170.75, 'text': '7513 ', 'id': 2}
# {'image_id': 0, 'category_id': 3, 'bbox': [227.99305555555554, 371.0, 107.625, 14.0], 'area': 1506.75, 'text': '5280 dzbemew ', 'id': 3}
# {'image_id': 0, 'category_id': 4, 'bbox': [29.000000000000014, 36.0, 656.0, 335.0], 'area': 219760.0, 'id': 4}
# {'image_id': 0, 'category_id': 5, 'bbox': [82.62500000000001, 39.333333333333314, 398.36111111111103, 298.9166666666667], 'area': 119076.77546296295, 'id': 5}
# ...
